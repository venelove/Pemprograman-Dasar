# %% [markdown]
# <a href="https://colab.research.google.com/github/venelove/Pemprograman-Dasar/blob/main/Latihan_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
venelove = pd.read_csv('/content/mahasiswa.csv')
#import file csv

# %%
venelove.head()
#melihat 5 data teratas
# Out:
#      nim   nama           jurusan    umur nilai_akhir  kehadiran_pct  \
# 0  E0001   Aldi            Teknik     150        59.5           82.0
# 1  E0002   Budi            teknik    20.0        84.5           99.0
# 2  E0003  Citra            Energi      -5        56.2           78.0
# 3  E0004   Dewi            Teknik  twenty        63.0           99.0
# 4  E0005    Eka  Manajemen Energi    22.0         999           65.0
#
#   tanggal_daftar
# 0     2024-05-05
# 1     2024-02-14
# 2     2024-04-29
# 3     2024-08-02
# 4     2024-03-22

# %%
venelove.tail()
#melihat 5 data terakhir
# Out:
#       nim   nama      jurusan  umur nilai_akhir  kehadiran_pct tanggal_daftar
# 73  E0057  Fauzi       Energi  23.0        58.2           76.0     2024-02-05
# 74  E0039   Mita       Energi  23.0        77.2           79.0     2024-01-04
# 75  E0069  Salsa  Informatika  23.0        63.4           86.0     2024-04-14
# 76  E0031   Eros  Informatika  23.0        68.0           66.0     2024-02-27
# 77  E0026   Zara  Informatika  24.0        90.4           82.0     2024-11-24

# %%
venelove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             78 non-null     object
#  1   nama            78 non-null     object
#  2   jurusan         76 non-null     object
#  3   umur            76 non-null     object
#  4   nilai_akhir     76 non-null     object
#  5   kehadiran_pct   76 non-null     float64
#  6   tanggal_daftar  76 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 4.4+ KB

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
print("Jumlah duplikasi: ", venelove.duplicated().sum())
# Out:
# Jumlah duplikasi:  8

# %%
venelove.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", venelove.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           2
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
venelove['jurusan'] = venelove['jurusan'].fillna("Pembangkit Energi")

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              2
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
venelove['umur'] = venelove['umur'].fillna(23)

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       2
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
venelove['nilai_akhir'] = pd.to_numeric(venelove['nilai_akhir'], errors='coerce') #konversi tipe data menjadi numeric yaitu float

venelove['nilai_akhir'].mean()
# Out:
# np.float64(88.15384615384616)

# %%
venelove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     object
#  4   nilai_akhir     65 non-null     float64
#  5   kehadiran_pct   68 non-null     float64
#  6   tanggal_daftar  68 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.4+ KB

# %%
venelove['nilai_akhir'] = venelove['nilai_akhir'].fillna(88)
#sekarang isi missing value pada nilai_akhir dengan nilai rata-rata yg sudah di dapat sebelumnya

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       0
# kehadiran_pct     2
# tanggal_daftar    2
# dtype: int64

# %%
venelove['kehadiran_pct'] = pd.to_numeric(venelove['kehadiran_pct'], errors='coerce')
venelove['kehadiran_pct'].mean()
# Out:
# np.float64(82.13235294117646)

# %%
venelove['kehadiran_pct'] = venelove['kehadiran_pct'].fillna(82)

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       0
# kehadiran_pct     0
# tanggal_daftar    2
# dtype: int64

# %%
venelove['tanggal_daftar'] = venelove['tanggal_daftar'].fillna('2024-03-24')

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       0
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
venelove.jurusan.value_counts()
# Out:
# jurusan
# Energi               21
# Informatika          17
# Teknik               12
# Manajemen Energi     11
# Pembangkit Energi     2
# teknik                1
#  energi               1
# ManajemenEnergi       1
# EnErGi                1
# Teknik                1
# ENG                   1
# ENERGI                1
# Name: count, dtype: int64

# %%
venelove.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
venelove['jurusan'] = venelove['jurusan'].str.lower().str.strip()
#ubah menjadi huruf kecil

# %%
venelove.jurusan.value_counts()
# Out:
# jurusan
# energi               24
# informatika          17
# teknik               14
# manajemen energi     11
# pembangkit energi     2
# manajemenenergi       1
# eng                   1
# Name: count, dtype: int64

# %%
mapping_jurusan = {
    "energi": "Pembangkit Energi",
    " energi ": "Pembangkit Energi",
    "ENERGI": "Pembangkit Energi",
    "EnErGi": "Pembangkit Energi",
    "eng": "Pembangkit Energi",
    "teknik": "Pembangkit Energi",
    "Teknik ": "Pembangkit Energi",
    "teknik ": "Pembangkit Energi",
    "manajemenenergi": "Manajemen Energi",
    "manajemen energi": "Manajemen Energi"
}

# %%
venelove["jurusan"] = venelove["jurusan"].replace(mapping_jurusan)

# %%
venelove["jurusan"] = venelove["jurusan"].str.title()

# %%
venelove.jurusan.value_counts()
# Out:
# jurusan
# Pembangkit Energi    41
# Informatika          17
# Manajemen Energi     12
# Name: count, dtype: int64

# %%
print("Hasil setelah normalisasi dan pemetaan:")
print(venelove['jurusan'].value_counts())
# Out:
# Hasil setelah normalisasi dan pemetaan:
# jurusan
# Pembangkit Energi    41
# Informatika          17
# Manajemen Energi     12
# Name: count, dtype: int64

# %%
venelove.umur.value_counts()
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# twenty         1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
venelove['umur'] = venelove['umur'].replace('twenty', 20)

#bisa di lakuakn replace satu persatu seperti ini
# dari sebelumnya twenty menjadi 20

# %%
print(venelove['umur'].value_counts())
# Out:
# umur
# 23.0          15
# 25.0          10
# 20.0           9
# 24.0           9
# 22.0           8
# 19.0           7
# 21.0           4
# 23             2
# 150            1
# 20             1
# -5             1
# 120            1
# NaN_string     1
# 21years        1
# Name: count, dtype: int64

# %%
"""mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': np.nan,
    -5: np.nan,
    120: np.nan,
    150: np.nan
}
"""
# Out:
# "mapping_umur = {\n    'twenty': 20,\n    '21years': 21,\n    'NaN_string': np.nan,\n    -5: np.nan,\n    120: np.nan,\n    150: np.nan\n}\n"

# %%
venelove['umur'] = pd.to_numeric(venelove['umur'], errors='coerce')
venelove['umur'].mean()
# Out:
# np.float64(25.220588235294116)

# %%
mapping_umur = {
    'twenty': 20,
    '21years': 21,
    'NaN_string': 25,
    -5: 25,
    120: 25,
    150: 25
}

# %%
venelove['umur'] = venelove['umur'].replace(mapping_umur)

# %%
print("Hasil setelah pemetaan:")
print(venelove['umur'].value_counts())
print(f"\nTipe data kolom 'umur' sekarang: {venelove['umur'].dtype}")
# Out:
# Hasil setelah pemetaan:
# umur
# 23.0    17
# 25.0    13
# 20.0    10
# 24.0     9
# 22.0     8
# 19.0     7
# 21.0     4
# Name: count, dtype: int64
#
# Tipe data kolom 'umur' sekarang: float64

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              2
# nilai_akhir       0
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
venelove.head(50)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi  Pembangkit Energi  25.0         59.5           82.0
# 1   E0002    Budi  Pembangkit Energi  20.0         84.5           99.0
# 2   E0003   Citra  Pembangkit Energi  25.0         56.2           78.0
# 3   E0004    Dewi  Pembangkit Energi  20.0         63.0           99.0
# 4   E0005     Eka   Manajemen Energi  22.0        999.0           65.0
# 5   E0006   Fajar  Pembangkit Energi  21.0        -20.0           78.0
# 6   E0007    Gina        Informatika  19.0         70.2          150.0
# 7   E0008  Hendra  Pembangkit Energi  25.0         56.7          -10.0
# 8   E0009     Ika        Informatika  25.0         58.2           83.0
# 9   E0010    Joko  Pembangkit Energi  23.0         62.7           69.0
# 10  E0011    Kiki  Pembangkit Energi  25.0         66.6           70.0
# 11  E0012    Lina        Informatika  22.0         66.1           82.0
# ...

# %%
venelove.tail(50)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 20  E0021     Uli  Pembangkit Energi  24.0         78.4           90.0
# 21  E0022    Vina  Pembangkit Energi   NaN         75.4           70.0
# 22  E0023   Wawan  Pembangkit Energi  20.0         80.1           92.0
# 23  E0024    Xena        Informatika  22.0         70.3           94.0
# 24  E0025    Yudi  Pembangkit Energi  23.0         89.4           65.0
# 25  E0026    Zara        Informatika  24.0         90.4           82.0
# 26  E0027    Arif  Pembangkit Energi  19.0         66.7           75.0
# 27  E0028    Bima  Pembangkit Energi  24.0         90.0           81.0
# 28  E0029    Cici  Pembangkit Energi  23.0         91.5           84.0
# 29  E0030    Dani  Pembangkit Energi  20.0         88.0           75.0
# 30  E0031    Eros        Informatika  23.0         68.0           66.0
# 31  E0032   Ferry  Pembangkit Energi  25.0         87.3           80.0
# ...

# %%
venelove['umur'].mean()
# Out:
# np.float64(22.426470588235293)

# %%
venelove['umur'] = venelove['umur'].fillna(22)

# %%
venelove.isna().sum()
# Out:
# nim               0
# nama              0
# jurusan           0
# umur              0
# nilai_akhir       0
# kehadiran_pct     0
# tanggal_daftar    0
# dtype: int64

# %%
venelove.duplicated().sum()
# Out:
# np.int64(0)

# %%
venelove.head(55)
# Out:
#       nim    nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 0   E0001    Aldi  Pembangkit Energi  25.0         59.5           82.0
# 1   E0002    Budi  Pembangkit Energi  20.0         84.5           99.0
# 2   E0003   Citra  Pembangkit Energi  25.0         56.2           78.0
# 3   E0004    Dewi  Pembangkit Energi  20.0         63.0           99.0
# 4   E0005     Eka   Manajemen Energi  22.0        999.0           65.0
# 5   E0006   Fajar  Pembangkit Energi  21.0        -20.0           78.0
# 6   E0007    Gina        Informatika  19.0         70.2          150.0
# 7   E0008  Hendra  Pembangkit Energi  25.0         56.7          -10.0
# 8   E0009     Ika        Informatika  25.0         58.2           83.0
# 9   E0010    Joko  Pembangkit Energi  23.0         62.7           69.0
# 10  E0011    Kiki  Pembangkit Energi  25.0         66.6           70.0
# 11  E0012    Lina        Informatika  22.0         66.1           82.0
# ...

# %%
venelove.tail()
# Out:
#       nim   nama            jurusan  umur  nilai_akhir  kehadiran_pct  \
# 65  E0066   Oleh  Pembangkit Energi  23.0         94.4           98.0
# 66  E0067  Putri  Pembangkit Energi  24.0         59.1           82.0
# 67  E0068   Rafi        Informatika  19.0         84.7           74.0
# 68  E0069  Salsa        Informatika  23.0         63.4           86.0
# 69  E0070  Tasya   Manajemen Energi  23.0         74.5           68.0
#
#    tanggal_daftar
# 65     2024-01-05
# 66     2024-05-15
# 67     2024-05-19
# 68     2024-04-14
# 69     2024-02-17

# %%
venelove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nim             70 non-null     object
#  1   nama            70 non-null     object
#  2   jurusan         70 non-null     object
#  3   umur            70 non-null     float64
#  4   nilai_akhir     70 non-null     float64
#  5   kehadiran_pct   70 non-null     float64
#  6   tanggal_daftar  70 non-null     object
# dtypes: float64(3), object(4)
# memory usage: 4.4+ KB
